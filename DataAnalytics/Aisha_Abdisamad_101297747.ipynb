# %% [markdown]
# # BUSI 2401 Introduction to Data Analytics - Assignment 2
#
# Designed by Qi Deng (2025W)
#
# **Due date:** March 16, 2025 11:59 pm (est)
# **Weight:** 15% of final grade

# %% [markdown]
# **Please Enter your information here:**
# - Full Name: Aisha Abdisamad
# - Student ID: 101297747

# %% [markdown]
# **A few important notes:**
# 1. Please note that the our class has covered roughly 90-95% of the skills that you need to complete this assignment. There is 5-10% of the skills that you will need to figure out by searching external resources (e.g., Google, YouTube, Pandas website, Matplotlib website, etc.). This is designed on purpose because it is impossible to cover all Pandas and Matplotlib skills in a few classes, and it is a common practice for data analysts to refer to external resources to complete certain tasks.
# 2. This is an individual assignment. The use of any Generative AI (including ChatGPT), file sharing etc. will be considered an Academic Integrity offense. If we suspect any suspicious behaviour, we reserve the right to have you individually explain your code during office hours.

# %% [markdown]
# **Submission Guide**
# - Before submitting your assignment, please ensure that you run all cells in this Jupyter file so that all outputs are properly displayed beneath each cell. This step is crucial, as it allows our TAs to directly review your answers by checking the outputs, making the grading process more efficient. Failure to follow this rule will result in a 20% penalty on your grade. Save yourself (and us!) valuable time by double-checking your work before submission.
# - Rename this file as `YourFirstName_LastName_CarletonID.ipynb`, and submit on Brightspace

# %% [markdown]
# ## Trailer
# Welcome to your journey into the world of data analytics! 🎬📊 In this assignment, you will step into the role of a data analyst, using Pandas and Matplotlib to explore and visualize real-world movie data. Have you ever wondered what makes a movie a blockbuster? Do bigger budgets always lead to higher revenue? Through this assignment, you'll uncover insights from a vast dataset of movies, applying key data analysis techniques just like professionals in the industry. Get ready to filter, sort, analyze, and visualize—because in the world of data, every number tells a story! 🚀

# %% [markdown]
# ## Dataset
#
# The dataset is *`TMDB_movie_v11_sample.csv`*. This dataset contains 737,680 movies that were released from 1960 to 2023. Specifically, the dataset includes the following columns.
#
# - **id**: An arbitrary ID for the movie.
# - **title**: The official title of the movie.
# - **release_date**: Theatrical release date of the movie.
# - **language**: The language in which the movie was filmed.
# - **adult**: Whether the movie is for adults (TRUE/FALSE)
# - **production_companies**: A stringified list of production companies involved with the making of the movie.
# - **production_countries**: A stringified list of countries where the movie was filmed or produced.
# - **runtime**: Duration of the movie in minutes.
# - **popularity**: The Popularity Score assigned by TMDB.
# - **vote_average**: The average rating of the movie on TMDB.
# - **vote_count**: The number of votes by users, as counted by TMDB.
# - **budget**: The budget of the movie in dollars.
# - **revenue**: World-wide revenue of the movie in dollars.

# %% [markdown]
# ## Task 1: Get to know your data (2 marks)
#
# **Q1-1 (0.2 pts)** - For this assignment, you will need to use the following python libraries: 1) pandas; 2) numpy; 3) matplotlib.
# Please import these libraries properly in the cell below.

# %%
import pandas as pd # import pandas 
import numpy as np # import numpy
#import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# **Q1-2 (0.2 pts)** - Please load the dataset properly in the cell below (assuming the data file is in the same folder as the Jupyter File). Make sure you name the dataframe as `df`.

# %%
df = pd.read_csv('TMDB_movie_v11_sample.csv')
df
# Out:
#             id                   title release_date language  adult  \
# 0        27205               Inception   2010-07-15       en  False
# 1       157336            Interstellar   2014-11-05       en  False
# 2          155         The Dark Knight   2008-07-16       en  False
# 3        19995                  Avatar   2009-12-15       en  False
# 4        24428            The Avengers   2012-04-25       en  False
# ...        ...                     ...          ...      ...    ...
# 737675  755913     His Loving Daughter   1971-11-01       en   True
# 737676  755915   A Deal with the Devil   2020-07-17       en  False
# 737677  755916  SRTV 344 - Zezé Macedo   1977-01-01       pt  False
# 737678  755919   Split Enz: Spellbound   1993-07-08       en  False
# 737679  755920       Hollywood Harlots   1979-01-01       en   True
#
#                                      production_companies  \
# 0       Legendary Pictures, Syncopy, Warner Bros. Pict...
# ...

# %% [markdown]
# **Q1-3 (0.2 pts)** - How many rows and columns does this dataset contain? Write a code and write your answer as comment in the cell below.

# %%
df.shape
# 737680 rows and 13 columns
# Out:
# (737680, 13)

# %% [markdown]
# **Q1-4 (0.2 pts)** - Display the first 3 rows of the dataset.

# %%
df.head(3)
# Out:
#        id            title release_date language  adult  \
# 0   27205        Inception   2010-07-15       en  False
# 1  157336     Interstellar   2014-11-05       en  False
# 2     155  The Dark Knight   2008-07-16       en  False
#
#                                 production_companies  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1  Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2  DC Comics, Legendary Pictures, Syncopy, Isobel...
#
#                        production_countries  runtime  popularity  \
# 0  United Kingdom, United States of America      148      83.952
# 1  United Kingdom, United States of America      169     140.241
# 2  United Kingdom, United States of America      152     130.643
#
#    vote_average  vote_count     budget     revenue
# 0         8.364       34495  160000000   825532764
# 1         8.417       32571  165000000   701729206
# 2         8.512       30619  185000000  1004558444

# %% [markdown]
# **Q1-5 (0.4 pts)** - Are there any missing values? If yes, which columns have missing values? How many missing values do the dolumns have? Write a code and write your answer as comment in the cell below.

# %%
df.isnull().sum()

#Yes there are two columns that have missing values. 
#The columns that have missing values are the production_companies column and 
#the production_countries column. The production_companies columns has 376321 missing values
# and the production_countries coloumn has 296654 missing values.
# Out:
# id                           0
# title                        0
# release_date                 0
# language                     0
# adult                        0
# production_companies    376321
# production_countries    296654
# runtime                      0
# popularity                   0
# vote_average                 0
# vote_count                   0
# budget                       0
# revenue                      0
# dtype: int64

# %% [markdown]
# **Q1-6 (0.4 pts)** - What are the *min*, *max*, *mean* for the following columns: `runtime`, `popularity`, `vote_average`, `vote_count`? Write a code and write your answer as comment in the cell below.
# (NOTE: The code should display the required information at the same time. You should not use seperate code to get the required information for each column one by one.)

# %%
df[['runtime','popularity','vote_average','vote_count']].agg(['min','max','mean'])
#runtime: min: 0.000000, max: 14400.000000,  mean: 53.977428	
#popularity: min: 0.000000, max: 2994.357000,  mean: 1.454273	
#vote_average: min: 0.000000, max: 10.000000,  mean: 2.142675	
#vote_count: min: 0.000000, max: 34495.000000,  mean: 27.305894
# got the .agg() function from the Pandas - Getting started tutorials listed under week 7
# Out:
#            runtime   popularity  vote_average    vote_count
# min       0.000000     0.000000      0.000000      0.000000
# max   14400.000000  2994.357000     10.000000  34495.000000
# mean     53.977428     1.454273      2.142675     27.305894

# %% [markdown]
# **Q1-7 (0.2 pts)** - Based on the information you get in Q1-6, are there any values that seem to be abnormal. If yes, which values are abnormal and justify why? Use the Markdown cell below to enter your answer.

# %% [markdown]
# A movie having a runtime of 14,400 minutes is very abnormal because that is equivalent to almost 10 days and no movie runs for 10 days.

# %% [markdown]
# **Q1-8 (0.2 pts)** - Write a code to display the datatypes for the columns. What is the data type for `id`? Is it ideal, why? Write your answer as comment in the cell below.

# %%
df.dtypes

# The data type for id is an integer 
#Since id is an abritrary value it can take on any from based on random selection or personal whim meaning that the movie id can include alphanumeric values or special characters. 
#This makes the data type integer not ideal for id because an integer cannot take on those values.
# Out:
# id                        int64
# title                    object
# release_date             object
# language                 object
# adult                      bool
# production_companies     object
# production_countries     object
# runtime                   int64
# popularity              float64
# vote_average            float64
# vote_count                int64
# budget                    int64
# revenue                   int64
# dtype: object

# %% [markdown]
# ## Task 2: Exploratory Analysis (5 marks)
#
# **Q2-1 (0.5 pts)** - What are the top 10 most popular movies based on `vote_count`? Write a code and write your answer as comment in the cell below.

# %%
df.sort_values(by='vote_count', ascending=False).head(10)

#The top 10 most popular movies based on vote_count are Inception, Interstellar, The Dark Knight, Avatar, The Avengers, Deadpool, Avengers: Infinity War, Fight Club, Guardians of the Galaxy, and Pulp Fiction
# Out:
#        id                    title release_date language  adult  \
# 0   27205                Inception   2010-07-15  English  False
# 1  157336             Interstellar   2014-11-05  English  False
# 2     155          The Dark Knight   2008-07-16  English  False
# 3   19995                   Avatar   2009-12-15  English  False
# 4   24428             The Avengers   2012-04-25  English  False
# 5  293660                 Deadpool   2016-02-09  English  False
# 6  299536   Avengers: Infinity War   2018-04-25  English  False
# 7     550               Fight Club   1999-10-15  English  False
# 8  118340  Guardians of the Galaxy   2014-07-30  English  False
# 9     680             Pulp Fiction   1994-09-10  English  False
#
#                                 production_companies  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1  Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2  DC Comics, Legendary Pictures, Syncopy, Isobel...
# ...

# %% [markdown]
# **Q2-2 (0.5 pts)** - How many movies meet the following conditions:
# - has a `budget` above \$100 million or `revenue` above \$500 million
# - has a `vote_average` above 8
# - has a `vote_count` above 5000
#
# Write a code to extract and display those movies (i.e., rows) and write your answer as comment in the cell below.

# %%
movie_condition = df[((df.budget >100000000) |(df.revenue >500000000)) & (df.vote_average >8) & (df.vote_count >5000) ]
movie_condition.shape[0]
movie_condition
# the number of rows that meet this condition is 22
# Out:
#          id                                              title release_date  \
# 0     27205                                          Inception   2010-07-15
# 1    157336                                       Interstellar   2014-11-05
# 2       155                                    The Dark Knight   2008-07-16
# 6    299536                             Avengers: Infinity War   2018-04-25
# 10       13                                       Forrest Gump   1994-06-23
# 15   299534                                  Avengers: Endgame   2019-04-24
# 18   475557                                              Joker   2019-10-01
# 19      120  The Lord of the Rings: The Fellowship of the Ring   2001-12-18
# 20      122      The Lord of the Rings: The Return of the King   2003-12-01
# 35      121              The Lord of the Rings: The Two Towers   2002-12-18
# 38      673           Harry Potter and the Prisoner of Azkaban   2004-05-31
# ...

# %% [markdown]
# **Q2-3 (1.5 pts: 0.5 pts/question)** - Create a new column `profit` by subtracting `budget` from `revenue` (i.e., profit = revenue - budget). What are the top 5 most profitable movies (highest profit)? Which 5 movies have the lowest profits (note: profits can be negative)? Write your codes to create the new column, then extract and display those movies (i.e., rows) and write your answer as comment in the cells. For this question, you can use multiple cells.

# %%
df['profit'] = df['revenue'] - df['budget']

# %%
low_profit_movies = df.sort_values(by='profit', ascending=False).head(5)
low_profit_movies

# the 5 most profitable movies are: TikTok Rizz Party, Avatar, Avengers: Endgame, Adventures in Bora Bora, Titanic
# Out:
#              id                    title release_date language  adult  \
# 177234  1270893        TikTok Rizz Party   2024-04-01       en  False
# 3         19995                   Avatar   2009-12-15       en  False
# 15       299534        Avengers: Endgame   2019-04-24       en  False
# 405509  1224207  Adventures in Bora Bora   2023-08-23       en  False
# 17          597                  Titanic   1997-11-18       en  False
#
#                                      production_companies  \
# 177234                                       Warner Bros.
# 3       Dune Entertainment, Lightstorm Entertainment, ...
# 15                                         Marvel Studios
# 405509                                                NaN
# 17      Paramount, 20th Century Fox, Lightstorm Entert...
#
#                             production_countries  runtime  popularity  \
# 177234                  United States of America      180       0.000
# ...

# %%
high_profit_movies = df.sort_values(by='profit', ascending=True).head(5)
high_profit_movies

# the 5 movies that have the lowest profit are: Enea, Denis Villeneuve’s Dune, Now That's What I Call Staxus! 2, Black Panther: Wakanda Forever, Angry Birds Plush: Egg Trilogy
# Out:
#              id                             title release_date language  \
# 351905  1057999                              Enea   2023-09-21  italian
# 390595  1417006           Denis Villeneuve’s Dune   2024-03-01  English
# 501062   622311  Now That's What I Call Staxus! 2   2016-05-19   German
# 392646  1383670    Black Panther: Wakanda Forever   2022-11-10  English
# 216217  1363342    Angry Birds Plush: Egg Trilogy   2021-05-08  English
#
#         adult                               production_companies  \
# 351905  False  The Apartment Pictures, Vision Distribution, F...
# 390595  False                                                NaN
# 501062   True                                             Staxus
# 392646  False                                                NaN
# 216217  False                                                NaN
#
#             production_countries  runtime  popularity  vote_average  \
# 351905                     Italy      115       4.319           0.0
# ...

# %% [markdown]
# **Q2-4 (0.5 pts)** - Which 3 movie languages have the highest average profit? Which 3 movie languages have the lowest average profit? Write your code to show the average profit for each language, sort the result from highest average profit to lowest average profit, and write your answer as comment in the cell below.
#
# NOTE: You need to specify the language, not the short two-letter codes when write your answers. For example, if you identify `en` as one of your answers, you need to write `English (en)`, instead of `en`. [HERE](https://en.wikipedia.org/wiki/List_of_ISO_639_language_codes) you can find a useful reference for languages and their two-letter codes.

# %%
movie_language_avg = df.groupby('language')['profit'].mean().sort_values(ascending= False)
highest_avg_profit = movie_language_avg.head(3)
lowest_avg_profit = movie_language_avg.tail(3)
print(lowest_avg_profit)
print(highest_avg_profit)

#The 3 movies languages with the Highest average profit are Russia(ru), Italian(it), German(de)
#The 3 movie languages with the lowest avergae profit are Korean(ko), Chinese(zh), and Ennglish(en)
# Out:
# language
# de    11371.496093
# it    -1614.144618
# ru   -28844.139590
# Name: profit, dtype: float64
# language
# en    914934.805754
# zh    910906.955610
# ko    379895.380681
# Name: profit, dtype: float64

# %% [markdown]
# **Q2-5 (0.5 pts)** - Following what you have done in Q2-4, referring to the WIKI website, please write a code to replace all languages in the dataframe with their full names (e.g., en should be replaced with English, etc.). Then, write a code to display all unique values of the `language` column.

# %%
language_list = {
    'en': 'English',
    'zh': 'Chinese',
    'ko': 'Korean',
    'ja': 'Japanese',
    'es':'Spanish',
    'pt': 'Portuguese',
    'fr': 'French',
    'de': 'German',
    'it': 'italian',
    'ru': 'Russian',  
}

df['language'] = df['language'].replace(language_list)

# %%
new_languages = df['language'].unique()
new_languages
# Out:
# array(['English', 'Korean', 'French', 'Japanese', 'italian', 'Spanish',
#        'Portuguese', 'German', 'Chinese', 'Russian'], dtype=object)

# %% [markdown]
# **Q2-6 (1 pts: 0.5 pts/question)** - How many movies are non-English movies? What are the top 3 most popular non-English movies based on vote_count? Write a code and write your answer as comment in the cell below. You can use multiple cells for this question. (A little fun fact - If your answer is correct, you will find my favourite French movie. I recommend it to all of you.)

# %%
non_english_movies = df[df['language'] != 'English']
non_english_movies.shape[0]
#There are 284049 non-english movies
# Out:
# 284049

# %%
top3 = non_english_movies.sort_values( by = 'vote_count', ascending= False).head(3)
top3
#The top 3 most popular non-english movies based on vote_count,
#Parasite, The Intouchables, Spirited Away
# Out:
#          id             title release_date  language  adult  \
# 81   496243          Parasite   2019-05-30    Korean  False
# 89    77338  The Intouchables   2011-11-02    French  False
# 107     129     Spirited Away   2001-07-20  Japanese  False
#
#                                   production_companies production_countries  \
# 81                                        Barunson E&A          South Korea
# 89   Gaumont, CinéCinéma, Quad Productions, Chaocor...               France
# 107                                      Studio Ghibli                Japan
#
#      runtime  popularity  vote_average  vote_count    budget    revenue  \
# 81       133      64.627         8.515       16430  11363000  257591776
# 89       113      41.656         8.277       16083  13000000  426588510
# 107      125      68.024         8.539       14913  19000000  274925095
#
#         profit
# 81   246228776
# 89   413588510
# 107  255925095

# %% [markdown]
# **Q2-7 (0.5 pts)** - How many movies are for adults (True in the `adult` column)? How many are not specifically for adults (False in the `adult` column)? Write a code and write your answer as comment in the cell below.

# %%
df['adult'].value_counts()

#There are 96998 movies that are for adults and 640682 movies that are not specifically for adults
# Out:
# adult
# False    640682
# True      96998
# Name: count, dtype: int64

# %% [markdown]
# ## Task 3: Visualize your data (5 marks)
#
# **Q3-1 (1 pts)** - What are the top 10 movies with highest revenue? Create a horizontal bar chart showing the top 10 movies with highest revenue. The chart should meet the following requirements:
# - The figure size should be `(10, 4)`
# - x-axis shows revenue and has a label `Revenue`
# - y-axis shows the movies and has a label `Movie Title`
# - Set the figure title as `Top 10 Movies by Revenue`.
# - Set the bar color to be `lightskyblue`

# %%
top_revenue = df.sort_values(by = 'revenue', ascending = False).head(10)
plt.figure(figsize = (10,4))
plt.barh(top_revenue['title'], top_revenue['revenue'], color='lightskyblue')
plt.xlabel('Revenue')
plt.ylabel('Movie Title')
plt.title('Top 10 Movies by Revenue')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# **Q3-2 (1 pts)** - Create a subset from `df`. The subset should be named as `movie_vote` and should only contain the movies of which `popularity` is higher than 30 and `revenue` is higher than \$100 millions. Using this new dataframe, create a scatter plot to visualize the relationship between `vote_count` and `vote_average`. The chart should meet the following requirements:
# - The figure size should be `(10, 6)`
# - x-axis shows vote count and has a label `Vote Count`
# - y-axis shows vote average and has a label `Vote Average`
# - Set the figure title as `Scatter Plot of Vote Count vs. Vote Average`.
# - For the scatters, set alpha as `0.5`
# - Display grid. The grid line should have the `dashed` linestyle
#
# After you create the chart, answer this question: Does a more votes lead to a higher vote score?
#
# Write a code and write your answer as comment in the cell below.

# %%
df_range = df[(df['popularity'] > 30) & (df['revenue'] > 100000000)]
movie_vote = df_range[['vote_count', 'vote_average']]
plt.figure(figsize=(10, 6))
plt.scatter(x= movie_vote["vote_count"], y= movie_vote["vote_average"], alpha=0.5)
plt.xlabel("Vote Count")
plt.ylabel("Vote Average")
plt.title("Scatter Plot of Vote Count vs. Vote Average")
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# Yes more votes leads to a higher score because we can see a clear linear trend in the chart below where lower vote counts are clustured in the lower to mid range of the chart (5-7) and higher vote counts a more spread out ranging in scores from an 8 or higher.

# %% [markdown]
# **Q3-3 (1 pts)** - How many movies were released for each year between 1960 and 2020? Create a line chart showing the trend of the movie release count over time (do not include data after 2020). The chart should meet the following requirements:
# - The figure size should be `(12, 4)`
# - x-axis shows time and has a label `Year`
# - y-axis shows the release count and has a label `Count`
# - Set the figure title as `Movie Release Count in 60 Years: 1960 to 2020`.
# - Use circle marker, the line should be solid line, and color of the line should be orange

# %%
df['release_year'] = df['release_date']
# use the pandas.to_datetime to convert the release date to a release year. This function converts a scalar, array-like, Series or DataFrame to a pandas datetime object.
df['release_year'] = pd.to_datetime(df['release_year']).dt.year
#set the 60 year range by setting release year greater than or equal to the year 1960 and less than the year 2020
released_movies = df[(df['release_year']>= 1960) & (df['release_year']< 2020)]
num_movies_released = released_movies['release_year'].value_counts().sort_index()

plt.figure(figsize=(12,4))
plt.plot(num_movies_released.index, num_movies_released.values, marker="o", linestyle="-", color="orange")
plt.xlabel("Year")
plt.ylabel("Count")
plt.title("Movie Release Count in 60 Years: 1960 to 2020")
plt.show()

# %% [markdown]
# **Q3-4 (2 pts)** - This is a follow up question of Q3-4.
#
# What are the average profits of movies released for each year for each language between 1960 and 2020? Create a line chart showing the trend of the movie average profits over time (Still, do not include data after 2020) for each language. So, in total, you should have 10 lines in the chart.
#
# The chart should meet the following requirements:
# - The figure size should be `(12, 6)`
# - x-axis shows time and has a label `Year`
# - y-axis shows the average profits and has a label `Average Profits per Movie`
# - Set the figure title as `Average Profits per Movie by Language in 60 Years: 1960 to 2020`.
# - The line should be solid line (do not apply markers in this chart.)
# - Each line should have a different color in the `Tableau Palette` (You can find color list [HERE](https://matplotlib.org/stable/gallery/color/named_colors.html).)
# - Show legend for all lines
#
# Check the chart and what do you find? Anything interesting? Any insights? Identify 3 trends/insights/patterns from the chart and write them in a markdown cell following your code cell below.

# %%
#create a list of tableau colours
color_list = ['tab:blue','tab:orange','tab:green','tab:red','tab:purple','tab:brown','tab:pink','tab:gray','tab:olive','tab:cyan']
top_ten_languages = df['language'].value_counts().head(10).index

plt.figure(figsize=(12,6))

color_index = 0
#use a for loop to loop through the language dictonary created earlier in Q2-5, this loop will output a new line as it loops through the languages while updating each line with a new color from the color list
for language in top_ten_languages:
    df_language = released_movies[released_movies['language'] == language].groupby('release_year')['profit'].mean().sort_index()
    plt.plot(df_language.index, df_language.values, linestyle="-", color= color_list[color_index],label = language)
    color_index+=1
    
plt.xlabel("Year")
plt.ylabel("Average Profits per Movie")
plt.title("Average Profits per Movie by Language in 60 Years: 1960 to 2020")   
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Three trend/insights/patterns I have noticed from the chart are:
#
# - The blue line that represents English movies shows how English movies are steadily dominating as they have the highest profits over time. Espically after the 1970's where they continue to steadily grow.
# - Non-english movies see dramatic increases and spikes in profits after and during the year 2000. Chinese movies see a large spike in the mid 2010s. This is likely because streaming services giants like Netflix started streaming Chinese movies in the mid 2010s resulting in an increased number of views of these movies.
# - If we look at the red line representing Japanese movies we see an initial spike in the late 1990 and an even bigger spike in the early 2000. I belive this is because anime which is a from of Japanese animation gain popularity globably around that time leading to increased profits in that sector.

# %% [markdown]
# ## Task 4: Critical Thinking & Open-Ended Research (3 marks)

# %% [markdown]
# **Q4-1 (2 pts)** -  Are better ratings always linked to higher revenue?
#
# - Analyze whether movies with better ratings generally generate higher revenue.
# - From the chart types that we have learned in our course so far, pick one that can bestly showcase such relationship and create the chart below with proper formatting.
# - Provide an interpretation of the results (e.g., Are high-rated movies consistently well-sold? Are there low-rated movies with high revenue?).
# - To clearly show the trend, you may need to apply a filter to only visualize a subset of the full dataset. You need to consider what filter to use.

# %%
average_rating_range = df[(df['revenue'] > 100000000)]
rating_revenue_trend = average_rating_range[['vote_average', 'revenue']]
plt.figure(figsize=(10, 6))
plt.scatter(x= rating_revenue_trend["vote_average"], y= rating_revenue_trend["revenue"], alpha=0.5)
plt.xlabel("Average Rating")
plt.ylabel("Revenue")
plt.title("Scatter Plot of Vote Average and Revenue")
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %% [markdown]
# There are three things we can interpret from the scatter plot including the lack of a clear lincear relationship between the two variables, the fact that there are high revenue movies with low ratings and the fact that almost all the movies cluster between a rating of 5 and 8 (the dense area of the graph). Firstly, there is not a strong relationship between higher ratings and higher revenue because there are some movies that have a high rating and high revenue but also movies that have a high rating but have low revenue. There are movies with low ratings for example a rating of 0 but still produce a higher revenue in the billions. I think this shows that other variables are at play here and not just vote_average. In conclusion better ratings do not always gurantee higher revenue.

# %% [markdown]
# **Q4-2 (1 pts)** - Find your favorite movie in this dataset. Write a code to show that moview details (i.e., the row for the movie). Then, depending on the data that we have about this movie, evaluate if you think the movie is a successful movie or not and justify why. Investigate and explain why it is successful or why it is not successful based on real-world factors (e.g., franchise recognition, marketing success, or poor reception despite high investment).
#
# This question is more like a qualitative analysis question. For this question, you answer need to be sounding and solid with good rationale. Also, your answer cannot be too short. Probably ~150 words could be a good length for the written answer. Use a markdown cell for your discussion answer.

# %%
favorite_movie = df[df['title'] == 'Interstellar']
favorite_movie
# Out:
#        id         title release_date language  adult  \
# 1  157336  Interstellar   2014-11-05  English  False
#
#                                 production_companies  \
# 1  Legendary Pictures, Syncopy, Lynda Obst Produc...
#
#                        production_countries  runtime  popularity  \
# 1  United Kingdom, United States of America      169     140.241
#
#    vote_average  vote_count     budget    revenue     profit  release_year
# 1         8.417       32571  165000000  701729206  536729206          2014

# %% [markdown]
# From the data above, we can see that Interstellar had an allocated budget of 165 million dollars and earned 701.7 million dollars in revenue. This resulted in a profit of 536.7 million, which is a very good return on the initial investment. This makes the movie financially successful.
#
# Interstellar was also directed by one of the most well-respected filmmakers, Christopher Nolan. His films have grossed over $6.6 billion globally, ranking him among the highest-earning directors. His achievements include nominations for multiple Academy Awards, with wins for Best Editing and Best Sound for Dunkirk. He has also won a Golden Globe Award and two British Academy Film Awards. Given his reputation, the film attracted significant attention and anticipation.
#
# The movie presents scientifically challenging concepts in an engaging and accessible way. Interstellar also features an outstanding cast, including Matthew McConaughey, Anne Hathaway, and Jessica Chastain. These factors contributed to the film’s critical and commercial success.

# %% [markdown]
# # Ending Note
#
# Great work! 🎉 By completing this assignment, you've taken a significant step toward mastering data analysis with Pandas and Matplotlib. You’ve learned how to filter, sort, aggregate, and visualize real-world data, just like professional data analysts in the business world.
#
# As a movie fan, I hope you found this assignment both engaging and insightful. And as a professor in Business Analytics, I sincerely hope this experience has sparked your curiosity and excitement for the fascinating world of data. Remember, data tells stories—just like movies do—and you now have the tools to uncover and interpret them. How exciting!
